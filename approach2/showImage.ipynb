# %%
# import dependences
# %pip install seaborn

from PIL import Image
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# 创建一个2行4列的子图布局
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 8))

# 图片路径
image_paths = [
    '../elpv-dataset/images/cell0004.png',
    '../elpv-dataset/images/cell0058.png',  
    '../elpv-dataset/images/cell0516.png',  
    '../elpv-dataset/images/cell0007.png',  
    '../elpv-dataset/images/cell0061.png',  
    '../elpv-dataset/images/cell0087.png',  
    '../elpv-dataset/images/cell0070.png',  
    '../elpv-dataset/images/cell0068.png',  
]

title = [
    'mono 0.0',
    'mono 0.333',  
    'mono 0.666',  
    'mono 1.0',  
    'poly 0.0',  
    'poly 0.33',  
   'poly 0.66',  
   'poly 1.0',  
    ]


# 遍历每个子图并显示转换后的灰度图
for ax, img_path, title in zip(axes.flat, image_paths, title):
    # 读取并转换图片为灰度
    img = Image.open(img_path).convert('L')
    img = np.array(img)
    ax.set_xlabel(title)
    # 显示灰度图
    ax.imshow(img, cmap='gray')
    ax.set_title(title)
    ax.axis('off')  # 关闭坐标轴

# 调整子图的布局
plt.tight_layout()

# 显示图表
plt.show()
